# %%
# write a python program to convert celsius to fahrenheit
# celcius_to_fahrenheit
celsius = float(input("Enter the temperature in celsius: "))
fahrenheit = (celsius * 9/5) + 32
print(f"the {celsius} degree celsius  is equal to {fahrenheit} degree fahrenheit")
# Out:
# the 54.0 degree celsius  is equal to 129.2 degree fahrenheit

# %%
# write a python program to convert fahrenheit to celsius
# fahrenheit_to_celsius
fahrenheit = float(input("Enter the temperature in fahrenheit: "))
celsius = (fahrenheit - 32) * 5/9
print(f"the {fahrenheit} degree fahrenheit is equal to {celsius} degree celsius. ")
# Out:
# the 2.0 degree fahrenheit is equal to -16.666666666666668 degree celsius.
